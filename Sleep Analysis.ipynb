# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\hp\\OneDrive\\Desktop\\Sleep data analysis\\Health_Sleep_Statistics.csv")

# %%
df.head()
# Out:
#    User ID  Age Gender  Sleep Quality Bedtime Wake-up Time  Daily Steps  \
# 0        1   25      f              8   23:00        06:30         8000
# 1        2   34      m              7   00:30        07:00         5000
# 2        3   29      f              9   22:45        06:45         9000
# 3        4   41      m              5   01:00        06:30         4000
# 4        5   22      f              8   23:30        07:00        10000
#
#    Calories Burned Physical Activity Level Dietary Habits Sleep Disorders  \
# 0             2500                  medium        healthy              no
# 1             2200                     low      unhealthy             yes
# 2             2700                    high        healthy              no
# 3             2100                     low      unhealthy             yes
# 4             2800                    high         medium              no
#
#   Medication Usage
# 0               no
# 1              yes
# 2               no
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   User ID                  100 non-null    int64
#  1   Age                      100 non-null    int64
#  2   Gender                   100 non-null    object
#  3   Sleep Quality            100 non-null    int64
#  4   Bedtime                  100 non-null    object
#  5   Wake-up Time             100 non-null    object
#  6   Daily Steps              100 non-null    int64
#  7   Calories Burned          100 non-null    int64
#  8   Physical Activity Level  100 non-null    object
#  9   Dietary Habits           100 non-null    object
#  10  Sleep Disorders          100 non-null    object
#  11  Medication Usage         100 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 9.5+ KB

# %%
df.isnull().sum()
# Out:
# User ID                    0
# Age                        0
# Gender                     0
# Sleep Quality              0
# Bedtime                    0
# Wake-up Time               0
# Daily Steps                0
# Calories Burned            0
# Physical Activity Level    0
# Dietary Habits             0
# Sleep Disorders            0
# Medication Usage           0
# dtype: int64

# %%
df.size
# Out:
# 1200

# %%
df.columns.size
# Out:
# 12

# %%
df.describe() #Neither kids nor senior citizend are taken into considerations
# Out:
#           User ID         Age  Sleep Quality   Daily Steps  Calories Burned
# count  100.000000  100.000000     100.000000    100.000000        100.00000
# mean    50.500000   36.010000       7.000000   6830.000000       2421.00000
# std     29.011492    8.454865       1.734964   2498.706736        281.06759
# min      1.000000   22.000000       4.000000   3000.000000       2000.00000
# 25%     25.750000   28.750000       5.750000   4750.000000       2175.00000
# 50%     50.500000   35.000000       7.500000   6750.000000       2400.00000
# 75%     75.250000   44.000000       8.250000   9000.000000       2700.00000
# max    100.000000   50.000000       9.000000  11000.000000       2900.00000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(['User ID'] , axis = 1 , inplace = True)

# %%
df.head()
# Out:
#    Age Gender  Sleep Quality Bedtime Wake-up Time  Daily Steps  \
# 0   25      f              8   23:00        06:30         8000
# 1   34      m              7   00:30        07:00         5000
# 2   29      f              9   22:45        06:45         9000
# 3   41      m              5   01:00        06:30         4000
# 4   22      f              8   23:30        07:00        10000
#
#    Calories Burned Physical Activity Level Dietary Habits Sleep Disorders  \
# 0             2500                  medium        healthy              no
# 1             2200                     low      unhealthy             yes
# 2             2700                    high        healthy              no
# 3             2100                     low      unhealthy             yes
# 4             2800                    high         medium              no
#
#   Medication Usage
# 0               no
# 1              yes
# 2               no
# 3               no
# 4               no

# %% [markdown]
# # 1. Age Vs Sleep Quality Analysis

# %%
age_sleep_quality_corr = df[['Age' , 'Sleep Quality']].corr()
age_sleep_quality_corr
# Out:
#                     Age  Sleep Quality
# Age            1.000000      -0.848356
# Sleep Quality -0.848356       1.000000

# %%
age_sleep_quality_corr['Age']
# Out:
# Age              1.000000
# Sleep Quality   -0.848356
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Age' , y ='Sleep Quality' , data = df)
plt.title("Age Vs Sleep Quality Analysis")
plt.xlabel('Age')
plt.ylabel('Sleep Quality')
plt.show()

# %% [raw]
# **INFERENCE**
# The sleep quality is inversally proportional to Age i.e, if age is increasing then, the sleep quality is decreasing. As we can see that using correlation matrix that the correlation value is very high.

# %% [markdown]
# # Creating Linear Relation using Linear relation Model**

# %%
from sklearn.linear_model import LinearRegression
age_sleep_quality_model = LinearRegression()

x=df[['Age']]
y = df['Sleep Quality']

age_sleep_quality_model.fit(x,y)
# Out:
# LinearRegression()

# %%
age_sleep_quality_model.intercept_
# Out:
# np.float64(13.268812023190646)

# %%
age_sleep_quality_model.coef_
# Out:
# array([-0.17408531])

# %%
age_sleep_quality_predictions = age_sleep_quality_model.predict(x)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Age' , y = 'Sleep Quality',data=df, label= 'Actual Values')
plt.plot(x , age_sleep_quality_predictions, color='green',label = "Prediction Values")
plt.legend()
plt.show()

# %% [markdown]
# # 2 Physical Activity Vs Sleep Quality

# %%
df['Physical Activity Level'].head()
# Out:
# 0    medium
# 1       low
# 2      high
# 3       low
# 4      high
# Name: Physical Activity Level, dtype: object

# %%
df['Sleep Quality'].head()
# Out:
# 0    8
# 1    7
# 2    9
# 3    5
# 4    8
# Name: Sleep Quality, dtype: int64

# %%
df['Gender'].head()
# Out:
# 0    f
# 1    m
# 2    f
# 3    m
# 4    f
# Name: Gender, dtype: object

# %%
sns.barplot(x="Gender" , y="Sleep Quality" , data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='Sleep Quality'>

# %% [raw]
# ** INFERENCE**
# While using this graph we can easily derive that the sleep quality in Females aee much better than that of Male

# %%
sns.barplot(x="Physical Activity Level" , y="Sleep Quality" , data = df)
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='Sleep Quality'>

# %% [raw]
# ** INDERENCE **
# We can inference from the graph of Physical Activity Vs Sleep quality that the sleep quality is good in people those who are doing high Physical Activity .

# %%
df['Physical Activity Level'].head()
# Out:
# 0    medium
# 1       low
# 2      high
# 3       low
# 4      high
# Name: Physical Activity Level, dtype: object

# %%
custom_codes = {'low': 1, 'medium':2, 'high':3}
df['Physical Activity Level'] = df['Physical Activity Level'].map(custom_codes)
df['Physical Activity Level'].head()
# Out:
# 0    2
# 1    1
# 2    3
# 3    1
# 4    3
# Name: Physical Activity Level, dtype: int64

# %%
sns.barplot(x='Gender', y = 'Physical Activity Level' , data = df )
# Out:
# <Axes: xlabel='Gender', ylabel='Physical Activity Level'>

# %% [raw]
# ** INFERENCE **
# Over all Physical Activity Level is more in Female as compared to Male as Female are doing Heavy Physical Activity and Males are doing Low Physical Activity.

# %% [markdown]
# # Find P Statistics And  T Statistics Values

# %%
from scipy import stats

sleep_quality_males = df[df['Gender']=='m']['Sleep Quality']
sleep_quality_females = df[df['Gender']=='f']['Sleep Quality']

Physical_activity_males = df[df['Gender']=='m']['Physical Activity Level']
Physical_activity_females = df[df['Gender']=='f']['Physical Activity Level']

# %% [markdown]
# # Lets findout t and p values for Sleep Quality Vs Gender & Physical Activity Vs Gender

# %%
t_sleep_quality , p_sleep_quality = stats.ttest_ind(sleep_quality_males , sleep_quality_females)

print(f"t_stats value for Sleep Quality vs Gender: {t_sleep_quality:.2f}")
print(f"p_stats value for Sleep Quality vs Gender: {p_sleep_quality:.2f}")
# Out:
# t_stats value for Sleep Quality vs Gender: -14.32
# p_stats value for Sleep Quality vs Gender: 0.00

# %% [raw]
# ** INFERENCE **
# we can say that t value  , sleep quality gets affected  by gender significantly
# And for p value we have strong evidence.

# %%
t_physical_activity , p_physical_activity = stats.ttest_ind(Physical_activity_males , Physical_activity_females)

print(f"t_stats value for Physical Activity vs Gender: {t_physical_activity:.2f}")
print(f"p_stats value for Physical Activity vs Gender: {p_physical_activity:.2f}")
# Out:
# t_stats value for Physical Activity vs Gender: -10.98
# p_stats value for Physical Activity vs Gender: 0.00

# %% [markdown]
# # Time of Sleep & Walking up vs Sleep Quality

# %%
df['Bedtime'].head()
# Out:
# 0    23:00
# 1    00:30
# 2    22:45
# 3    01:00
# 4    23:30
# Name: Bedtime, dtype: object

# %%
df['Wake-up Time'].head()
# Out:
# 0    06:30
# 1    07:00
# 2    06:45
# 3    06:30
# 4    07:00
# Name: Wake-up Time, dtype: object

# %%
def sleep_time_helper_function(str_time):
  h = str_time.split(":")[0]
  m = str_time.split(":")[1]
  return int(h) +int( m)/60


df['Bedtime'] = df['Bedtime'].apply(sleep_time_helper_function)
df['Wake-up Time'] = df['Wake-up Time'].apply(sleep_time_helper_function)

# %%
df['Bedtime'].head()
# Out:
# 0    23.00
# 1     0.50
# 2    22.75
# 3     1.00
# 4    23.50
# Name: Bedtime, dtype: float64

# %%
df['Sleep Duration Hours'] =(df['Wake-up Time'] - df['Bedtime'])% 24
df['Sleep Duration Hours'].head()
# Out:
# 0    7.5
# 1    6.5
# 2    8.0
# 3    5.5
# 4    7.5
# Name: Sleep Duration Hours, dtype: float64

# %%
df.head()
# Out:
#    Age Gender  Sleep Quality  Bedtime  Wake-up Time  Daily Steps  \
# 0   25      f              8    23.00          6.50         8000
# 1   34      m              7     0.50          7.00         5000
# 2   29      f              9    22.75          6.75         9000
# 3   41      m              5     1.00          6.50         4000
# 4   22      f              8    23.50          7.00        10000
#
#    Calories Burned  Physical Activity Level Dietary Habits Sleep Disorders  \
# 0             2500                        2        healthy              no
# 1             2200                        1      unhealthy             yes
# 2             2700                        3        healthy              no
# 3             2100                        1      unhealthy             yes
# 4             2800                        3         medium              no
#
#   Medication Usage  Sleep Duration Hours
# 0               no                   7.5
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Bedtime' , y ='Sleep Quality' , data = df)
# Out:
# <Axes: xlabel='Bedtime', ylabel='Sleep Quality'>

# %% [raw]
# ** INFERENCE **
# Over all sleep quality  is less when bedtime is 1 , 1.25 , 1.5 and Sleep quality is high when people go to bed by 22 , 22.5 and so on.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Wake-up Time' , y = 'Sleep Quality' , data = df)
# Out:
# <Axes: xlabel='Wake-up Time', ylabel='Sleep Quality'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Sleep Duration Hours' , y = 'Sleep Quality' , data = df)
# Out:
# <Axes: xlabel='Sleep Duration Hours', ylabel='Sleep Quality'>

# %% [raw]
# ** INFERENCE **
# You should sleep about 8 - 8.5 hours to get good sleep quality.

# %%
sleep_duration_quality_model = LinearRegression()

x= df[['Sleep Duration Hours']]
y = df['Sleep Quality']
sleep_duration_quality_model.fit(x,y)
# Out:
# LinearRegression()

# %%
sleep_duration_quality_model.coef_
# Out:
# array([1.36940999])

# %%
sleep_duration_quality_model.intercept_
# Out:
# np.float64(-2.575599349763152)

# %%
predictions = sleep_duration_quality_model.predict(x)

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='Sleep Duration Hours' , y ='Sleep Quality' , data = df , label = 'Actual Values')
plt.plot(x,predictions , color ='green' , label = 'Predicted Values')
plt.legend()
plt.show()

# %% [raw]
# ** INFERENCE **
#  From this we are clear that sleep duration hours are also very important fro our sleep quality.

# %%
df.head()
# Out:
#    Age Gender  Sleep Quality  Bedtime  Wake-up Time  Daily Steps  \
# 0   25      f              8    23.00          6.50         8000
# 1   34      m              7     0.50          7.00         5000
# 2   29      f              9    22.75          6.75         9000
# 3   41      m              5     1.00          6.50         4000
# 4   22      f              8    23.50          7.00        10000
#
#    Calories Burned  Physical Activity Level Dietary Habits Sleep Disorders  \
# 0             2500                        2        healthy              no
# 1             2200                        1      unhealthy             yes
# 2             2700                        3        healthy              no
# 3             2100                        1      unhealthy             yes
# 4             2800                        3         medium              no
#
#   Medication Usage  Sleep Duration Hours
# 0               no                   7.5
# ...

# %% [markdown]
# # Daily Steps Vs Sleep Quality

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Daily Steps' , y = 'Sleep Quality' , data = df)
# Out:
# <Axes: xlabel='Daily Steps', ylabel='Sleep Quality'>

# %% [raw]
# *INFERENCE *
# Sleep quality enhances if our daily steps are more than 9000 and so.

# %% [markdown]
# # Calories Burned Vs Sleep Quality

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Calories Burned' , y = 'Sleep Quality' , data = df)
# Out:
# <Axes: xlabel='Calories Burned', ylabel='Sleep Quality'>

# %% [raw]
# * INFERENCE *
# We can see that if the sleep cycle is around 8 or more hours then our calories burn more.

# %% [markdown]
# # Dietary Habits vs Sleep Quality

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Dietary Habits' , y = 'Sleep Quality' , data = df)
# Out:
# <Axes: xlabel='Dietary Habits', ylabel='Sleep Quality'>

# %%
Dietary_habits_map = {'healthy': 1 , 'unhealthy':2 , 'medium':3}
df['Dietary Habits'] = df['Dietary Habits'].map(Dietary_habits_map)
df['Dietary Habits'].head()
# Out:
# 0    1
# 1    2
# 2    1
# 3    2
# 4    3
# Name: Dietary Habits, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Dietary Habits' , y = 'Sleep Quality' , data = df)
# Out:
# <Axes: xlabel='Dietary Habits', ylabel='Sleep Quality'>

# %% [raw]
# ** INFERENCE **
# We can see that those people are healhty who takes more than 8 hours of sleep.

# %% [markdown]
# # Medication Usage Vs Sleep Quality

# %%
Medication_Usage_map = {'yes':1 , 'no':0}
df['Medication Usage'] = df['Medication Usage'].map(Medication_Usage_map)
df['Medication Usage'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: Medication Usage, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Medication Usage' , y = 'Sleep Quality' , data = df)
# Out:
# <Axes: xlabel='Medication Usage', ylabel='Sleep Quality'>

# %% [raw]
# ** INFERENCE **
# We can see that those whose take medications have low sleep quality , and those who doesnot take any medication have good sleep quality near about 87 to 8 hours.

# %% [markdown]
# # Sleep Disorder Vs Sleep Quality

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x= "Sleep Disorders" , y = 'Sleep Quality' , data = df)
plt.show()

# %% [raw]
# ** INFERENCE **
# The people who are not having sleep disorders they are having highets sleep quality , and there is one outlier which is the person who have sleep disorder but still have a good sleep quality

# %%
df_numeric_features = df.select_dtypes(include=['int64' , 'float64'])
df_numeric_features.head()
# Out:
#    Age  Sleep Quality  Bedtime  Wake-up Time  Daily Steps  Calories Burned  \
# 0   25              8    23.00          6.50         8000             2500
# 1   34              7     0.50          7.00         5000             2200
# 2   29              9    22.75          6.75         9000             2700
# 3   41              5     1.00          6.50         4000             2100
# 4   22              8    23.50          7.00        10000             2800
#
#    Physical Activity Level  Dietary Habits  Medication Usage  \
# 0                        2               1                 0
# 1                        1               2                 1
# 2                        3               1                 0
# 3                        1               2                 0
# 4                        3               3                 0
#
#    Sleep Duration Hours
# 0                   7.5
# 1                   6.5
# 2                   8.0
# 3                   5.5
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_numeric_features.corr())
plt.show()

# %% [raw]
# ** INFERENCE**
# we have some good features such as sleep duration hours , physical activity level ,calories burned ,daily steps ,bedtime , sleep quality and age theses are very good features which telles us more about the relations.
